# %% [markdown]
# <a href="https://colab.research.google.com/github/Haripriya-2003/org_details/blob/master/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# practice coding problems in python
